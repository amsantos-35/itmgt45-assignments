# %% [markdown]
# 185767
# Santos
# 3 BS Information Technology Entrepreneurship

# %%
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}


def relationship_status(from_member, to_member):
    if from_member in social_graph [to_member] ["following"] and to_member in social_graph [from_member] ["following"]:
        return "friends"
    elif from_member in social_graph [to_member] ["following"]:
        return "followed by"
    elif to_member in social_graph [from_member] ["following"]:
        return "follower"
    else:
        return None

from_member=str(input("From: "))
to_member=str(input("To: "))

                
print(relationship_status(from_member, to_member))
# Out:
# From: @joeilagan
# To: @chums
# friends

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]


def get_winner(a):
     winner = None

     ## guides to your approach:
     ## check diagonals
     if len(set([a[i][i] for i in range(len(a))]))==1:
        return a[0][0]
     elif len(set([a[i][len(a)-i-1] for i in range(len(a))]))==1:
        return a[0][len(a)-1]

     ## check rows
     for i in range(len(a)-1):
        if (a[i][i]!=None) and (a[i][0]==a[i][1]) and (a[i][1]==a[i][2]):
            return a[i][i]
        else: continue
    
     ## check columns
     for i in range(len(a)-1):
        if (a[i][0]!=None) and (a[i][0]==a[i+1][0]) and (a[i+1][0]==a[i+2][0]):
            return a[i][0]
        else: continue
            
print(get_winner(board1))
print(get_winner(board6))
print(get_winner(board3))
# Out:
# X
# None
# O

# %%
locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
       # nice
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     }
}


def eta(source,destination):

    if source==destination:
        return 0
    elif (source,destination) in legs.keys():
        return legs[(source, destination)]["travel_time_mins"]
    else:
        new=list(legs.keys())
        a=[]
        b=[]
        for x in new:
            a.append(x[0])
            b.append(x[1])

    time=legs[source]["travel_time_mins"]+legs[destination]["travel_time_mins"]
    
    return time
        
s=str(input("Enter Source: "))
d=str(input("Enter Destination: "))

print("ETA: ",eta(s,d))
# Out:
# Enter Source: admu
# Enter Destination: dlsu
# ETA:  35
